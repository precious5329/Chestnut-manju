# %%
import math
import matplotlib.pyplot as plt

# Chestbun Parameters from research
chestnut_diamiater_cm = 3.1
chestnut_radius_cm = chestnut_diamiater_cm / 2
chestnut_volume_cm3 = (4/3) * math.pi * (chestnut_radius_cm ** 3)
chest_nut_volume_m3 = chestnut_volume_cm3  * 1e-6 #conversion to cubic meters

# Assumptions for the solar system (approximated)
solar_system_radius_meters = 4.545e9
solar_system_volume_m3 = (4/3) * math.pi * (solar_system_radius_meters ** 3)

# Lists to store volumes and time
volumes = []
minutes = []

# Function to calculate how many times it will double to fill a space
def calculate_doubling_times(initial_volume, target_volume):
  doubling_times = 0
  while initial_volume < target_volume:
      initial_volume *= 2
      volumes.append(initial_volume)
      doubling_times += 5 # Doubling every five minutes
      minutes.append(doubling_times)
  return doubling_times

# Calculating the time to fill the solar system with chestnut buns
time_to_fill_solar_system = calculate_doubling_times(chest_nut_volume_m3, solar_system_volume_m3)

# Print the result
print(f"it will take {time_to_fill_solar_system} minutes to cover the solar system with chestnut buns.")

# Visualize how volumes increase over time
plt.figure(figsize=(10, 6))
plt.plot(minutes, volumes)
plt.xlabel("Time (minutes)")
plt.ylabel("volume (cubic meters)")
plt.title("Chestnut Bun Volume Increase Over Time")
plt.grid(True)
plt.show()
# Out:
# it will take 575 minutes to cover the solar system with chestnut buns.

# %%
ball_radius_cm = 11 # Radius of ball in centimeters
ball_volume_cm3 = (4/3) * math.pi * (ball_radius_cm ** 3)
ball_volume_m3 = ball_volume_cm3 * 1e-6 # convert to cubic meters

# Volume of the tokyo dome from research
tokyo_dome_volume_m3 = 1240000

# Calculate the time it will take to fill the tokyo dome with a ball
time_to_fill_tokyo_dome = calculate_doubling_times(ball_volume_m3, tokyo_dome_volume_m3)

# Print the result
print(f"it will take {time_to_fill_tokyo_dome} minutes to cover the tokyo dome with a ball.")
# Out:
# it will take 140 minutes to cover the tokyo dome with a ball.
